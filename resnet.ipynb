# %%
import tensorflow as tf 
print(tf.__version__)
# Out:
# WARNING:tensorflow:From c:\anaconda_test\envs\tf\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
from PIL import Image
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
model = tf.keras.applications.ResNet50(weights='imagenet')
# Out:
# WARNING:tensorflow:From c:\anaconda_test\envs\tf\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\anaconda_test\envs\tf\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
img_path = "catanddog.jpg"

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
img = Image.open(img_path)  
img = img.resize((224, 224))
img_array = image.img_to_array(img)
plt.imshow(img_array.astype('uint8'))
plt.axis('off')
plt.show()
img_array = preprocess_input(img_array)
img_array = tf.expand_dims(img_array, 0)
print(img_array)

# %%
predictions = model.predict(img_array)
# Out:
# 1/1 [==============================] - 0s 362ms/step

# %%
decoded_predictions = decode_predictions(predictions, top=1)[0]
for i, (imagenet_id, label, score) in enumerate(decoded_predictions):
    print(f"{i + 1}: {label} ({score:.2f})")
# Out:
# 1: German_shepherd (0.38)
# 2: bloodhound (0.06)
# 3: Rhodesian_ridgeback (0.03)
# 4: Rottweiler (0.02)
# 5: Great_Dane (0.02)
# 6: malinois (0.02)
# 7: Doberman (0.01)
# 8: redbone (0.01)
# 9: Egyptian_cat (0.01)
# 10: tabby (0.01)
